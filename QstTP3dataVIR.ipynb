# %% [markdown]
# ### 🧮 2.1 إحصاءات وصفية
#
# #### 📊 الوسط والانتشار
# بعد حساب `mean` و`median` و`mode` و`std` و`range` لعمود **traffic_volume**، قارن الوسيط بالمتوسط لتقييم التناظر.
#
# **إجابة Q1:**
# إذا كان المتوسط أكبر من الوسيط بفارق واضح فالتوزيع يميل لانحراف موجب، وإن كانا متقاربين فالتوزيع أقرب للتناظر؛ عادةً بيانات المرور بالساعة تميل لقِمم الذروة مع ذيل يمين خفيف إلى متوسط.
#
# **إجابة Q2:**
# انحراف موجب متوقع غالباً بسبب ساعات الذروة الصباحية والمسائية التي ترفع الطرف الأيمن من التوزيع مقارنةً بالساعات الهادئة.
#
# ---
#
# #### 📈 الالتواء والحدبة
# بعد حساب `skewness` و`kurtosis` لعمود **traffic_volume** فسّر الإشارة والقيمة.
#
# **إجابة Q1:**
# قيمة `skew` الموجبة تشير إلى ذيل أيمن؛ كلما زادت القيمة زادت لا تناظرية التوزيع، وهذا غالباً يطابق الاستنتاج من مقارنة المتوسط والوسيط في الخطوة السابقة.
#
# **إجابة Q2:**
# إذا كانت `kurtosis` موجبة (تعريف فيشر)، فالتوزيع **Leptokurtic** بذيول أثقل من الطبيعي، وسالبة تعني **Platykurtic**؛ وجود ساعات ذروة أو حالات خاصة يمكن أن يزيد من ثِقَل الذيول.
#
# ---
#
# #### 🌦️ تجميع متعدد المتغيرات حسب الطقس
# باستخدام `groupby` على **weather_main** واحسب `mean` و`std` للـ **traffic_volume** لكل فئة.
#
# **الإجابة:**
# الفئة ذات أعلى متوسط هي التي تعود بأعلى `mean` في ناتجك؛ غالباً ظروف الطقس الشائعة مثل **“Clouds”** أو **“Clear”** تظهر متوسطات أعلى لا سيما بتداخلها مع ساعات الذروة، بينما أعلى `std` قد يظهر في فئات أقل تكراراً أو المرتبطة بتقلبات كبيرة مثل بعض حالات الأمطار/الثلوج، لكن الحسم من الجدول الناتج لديك.
#
# ---
#
# ### 📉 2.2 الرسوم والتباين
#
# #### 📊 هيستوغرام
# ارسم هيستوغرام مع خط المتوسط وعنوان فعّال ومحاور معنونة لإظهار شكل التوزيع.
#
# **إجابة صندوقي IQR:**
# بعد استخراج `Q1` و`Q3`، فإن
# \[
# IQR = Q3 - Q1
# \]
# إذا كان الـ IQR كبيراً مقارنة بالمدى فهذا يشير إلى انتشار جوهري في الكتلة المركزية، أما إذا كان الـ IQR صغيراً والمدى كبيراً فهذا يعني أن التباين مدفوع بذُيول/قيم متطرفة خارج الربعين الوسطين.
#
# ---
#
# #### 🗓️ صندوقيات مجمعة حسب العطل
# باستخدام **holiday**، قارن الوسيط والانتشار بين “None” والعطل.
# غالباً العطل تُظهر وسطاء أقل وتشتتاً مختلفاً بسبب انخفاض الرحلات اليومية المنتظمة، لكن التقييم النهائي من الصندوقيات المرسومة لديك، مع الاعتماد على الموضع أكثر من اللون لتوضيح الفروق.
#
# ---
#
# ### 🔥 2.3 الارتباط والـ Heatmap
# احسب مصفوفة الارتباط للأعمدة الرقمية:
# `traffic_volume`, `temp`, `rain_1h`, `snow_1h`, `clouds_all`
# ثم ارسم **heatmap**.
#
# **إجابة ارتباط Q:**
# عادةً `temp` يظهر أقوى ارتباط مطلق ضعيف وإيجابي مع **traffic_volume**، بينما `rain_1h`, `snow_1h`, و`clouds_all` تكون ارتباطاتها قريبة من الصفر، لكن اعتمد على القيم المحسوبة لديك لتحديد الأقوى واتجاهه بدقة.
#
# **مفارقة سمبسون والسببية:**
# حتى مع وجود ارتباط، لا يعني السببية؛ متغيرات غير مقاسة مثل ساعة اليوم، يوم الأسبوع، الموسم، أو أحداث محلية قد تقود كلاً من الطقس وحجم المرور معاً، ما يخلق علاقة ظاهرية عند التجميع وقد تنعكس أو تختفي عند التقسيم حسب الوقت.
#
# ---
#
# ### ⚙️ 2.4 الرسم التفاعلي الاختياري
# أنشئ **Scatter Plot** تفاعلي بين `temp` و`traffic_volume` مع خاصية **hover** لعرض `weather_description` وعنوان فعّال يلخّص الملاحظة (مثل تراجع المرور عند درجات قصوى).
# يساعد هذا على استكشاف العلاقة الضعيفة الملاحظة في المصفوفة دون الادعاء بالسببية.
